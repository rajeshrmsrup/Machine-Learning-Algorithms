# %% [markdown]
# # k-mean clustering

# %%
# k-mean clustering
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
x = [4, 5, 10, 4, 3, 11, 14, 6, 10, 12, 2, 4, 5, 10, 12, 13, 9, 8, 7, 11]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21, 16, 15, 17, 18, 20, 21, 21, 15, 19, 18]
data = list(zip(x,y))
print(data)

# import warnings
# warnings.filterwarnings('ignore')
# inertias = []
# for i in range(1, 21):
#     kmeans = KMeans(n_clusters=i)
#     kmeans.fit(data)
#     inertias.append(kmeans.inertia_)
    
# plt.plot(range(1, 21), inertias, maker = 'o')
# plt.title("Elbow method")
# plt.xlabel("Number of clusters")
# plt.ylabel("Inertia")

kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
plt.scatter(x, y, c=kmeans.labels_)
plt.show()
# Out:
# [(4, 21), (5, 19), (10, 24), (4, 17), (3, 16), (11, 25), (14, 24), (6, 22), (10, 21), (12, 21), (2, 16), (4, 15), (5, 17), (10, 18), (12, 20), (13, 21), (9, 21), (8, 15), (7, 19), (11, 18)]
